# %% [markdown]
# # type-1, type-2のワイル半金属における非相反伝導

# %%
using Distributed
addprocs(30)
# Out:
# ERROR: Unable to load dependent library C:\Users\Michishita\AppData\Local\Programs\Julia-1.7.1\bin\../bin/libjulia-internal.dll
# Assertion failed: addr && "Cannot map RO view", file /cygdrive/c/buildbot/worker/package_win64/build/src/cgmemmgr.cpp, line 153
#
# signal (22): SIGABRT
# in expression starting at none:0
# Message:The paging file is too small for this operation to complete.
# Assertion failed: addr && "Cannot map RO view", file /cygdrive/c/buildbot/worker/package_win64/build/src/cgmemmgr.cpp, line 153
#
# signal (22): SIGABRT
# in expression starting at none:0
# ERROR: could not load library "C:\Users\Michishita\AppData\Local\Programs\Julia-1.7.1\lib\julia\sys.dll"
# The paging file is too small for this operation to complete.
# ERROR: Unable to load dependent library C:\Users\Michishita\AppData\Local\Programs\Julia-1.7.1\bin\../bin/libjulia-internal.dll
# ...
