# %%
using Plots
using CSV
using DataFrames

# %%
rd = CSV.read("./Kt_BI.csv", DataFrame)
# Out:
# 100×16 DataFrame
#  Row │ x1            x2            x3           x4            x5           x6  ⋯
#      │ Float64       Float64       Float64      Float64       Float64      Flo ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ -0.000887035   0.00170944   0.00030957   -0.000715608   0.0104612   0.0 ⋯
#    2 │ -0.00179538    0.00346276   0.000559337  -0.00116086    0.0209286   0.0
#    3 │ -0.00272242    0.0052498    0.000748371  -0.00133594    0.0313551   0.0
#    4 │ -0.00366545    0.0070605    0.000876189  -0.00124237    0.0416947   0.0
#    5 │ -0.00462176    0.0088849    0.000942736  -0.000882944   0.0519021   0.0 ⋯
#    6 │ -0.00558857    0.0107132    0.00094837   -0.000261667   0.0619335   0.0
#    7 │ -0.00656309    0.0125359    0.000893843   0.000616325   0.0717462   0.0
#    8 │ -0.00754249    0.0143435    0.000780273   0.00174484    0.0812989   0.0
# ...

# %%
plot(rd[:,5], linewidth=3.0, gridwidth=3.0)
plot!(rd[:,4], linewidth=3.0, gridwidth=3.0)
plot!(rd[:,9], linewidth=3.0, gridwidth=3.0)
