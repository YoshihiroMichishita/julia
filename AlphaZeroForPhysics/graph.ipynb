# %%
using LinearAlgebra
using CSV
using DataFrames
using Plots
Plots.scalefontsizes(1.3)

# %%
read_data = CSV.read("./hists_mt25_1121.csv", DataFrame)
# Out:
# 5000×5 DataFrame
#   Row │ hist1      hist2      hist3      hist4      hist5
#       │ Float64    Float64    Float64    Float64    Float64
# ──────┼───────────────────────────────────────────────────────
#     1 │ -12.0      -12.0      -12.0      -12.0      -12.0
#     2 │   5.9812     5.9812     5.9812     1.33155    1.33155
#     3 │   5.9812     5.9812     5.9812     5.9812     5.9812
#     4 │   8.90101    5.9812     8.90101    8.90101    8.90101
#     5 │   8.90101    5.9812     8.90101    8.90101    8.90101
#     6 │   8.90101    8.90101    8.90101    8.90101    8.90101
#     7 │   8.90101    8.90101    8.90101    8.90101    8.90101
#     8 │   8.90101    8.90101    8.90101    8.90101    8.90101
#   ⋮   │     ⋮          ⋮          ⋮          ⋮          ⋮
#  4994 │  11.3393    11.3431    11.3592    11.3592    10.8844
#  4995 │  11.3393    11.3431    11.3592    11.3592    10.8844
#  4996 │  11.3393    11.3431    11.3592    11.3592    10.8844
#  4997 │  11.3393    11.3431    11.3592    11.3592    10.8844
#  4998 │  11.3393    11.3431    11.3592    11.3592    10.8844
#  4999 │  11.3393    11.3431    11.3592    11.3592    10.8844
#  5000 │  11.3393    11.3431    11.3592    11.3592    10.8844
#                                              4985 rows omitted

# %%
p =plot(read_data[:, 1], linewidth=3.0, xaxis=:log, xticks=([1,10,100,1000]), xlabel="iterate", yrange=(0,12), ylabel="max score", gridwidth=2.0,label="trial1", title="searching dynamics")
for it in 2:5
    p=plot!(read_data[:, it], linewidth=3.0,label="trial$(it)")
end

p
#savefig(p, "./hists_mt25_1121.pdf")

# %%
p =plot(read_data[:, 1], linewidth=3.0, xaxis=:log, xticks=([1,10,100,1000]), xlabel="iterate", yrange=(11.2,11.5), ylabel="max score", gridwidth=2.0,label=nothing, title="searching dynamics")
for it in 2:5
    p=plot!(read_data[:, it], linewidth=3.0,label=nothing)
end
#p = plot!(read_data2[:, 1], linewidth=3.0)
p
#savefig(p, "./hists_mt25_1121_zoom.pdf")

# %%
read_data2 = CSV.read("./hists_mt14_1121.csv", DataFrame)
# Out:
# 2000×5 DataFrame
#   Row │ hist1      hist2      hist3      hist4      hist5
#       │ Float64    Float64    Float64    Float64    Float64
# ──────┼───────────────────────────────────────────────────────
#     1 │ -12.0      -12.0      -12.0      -12.0      -12.0
#     2 │   1.33155    5.9812     5.9812     5.9812     5.9812
#     3 │   5.9812     5.9812     5.9812     5.9812     5.9812
#     4 │   5.9812     8.90101    8.90101    8.90101    8.90101
#     5 │   8.90101    8.90101    8.90101    8.90101    8.90101
#     6 │   8.90101    8.90101    8.90101    8.90101    8.90101
#     7 │   8.90101    8.90101    8.90101    8.90101    8.90101
#     8 │   8.90101    8.90101    8.90101    8.90101    8.90101
#   ⋮   │     ⋮          ⋮          ⋮          ⋮          ⋮
#  1994 │  11.3393    10.872     11.3393    11.3393    11.3393
#  1995 │  11.3393    10.872     11.3393    11.3393    11.3393
#  1996 │  11.3393    10.872     11.3393    11.3393    11.3393
#  1997 │  11.3393    10.872     11.3393    11.3393    11.3393
#  1998 │  11.3393    10.872     11.3393    11.3393    11.3393
#  1999 │  11.3393    10.872     11.3393    11.3393    11.3393
#  2000 │  11.3393    10.872     11.3393    11.3393    11.3393
#                                              1985 rows omitted
