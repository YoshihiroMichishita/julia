# %%
include("AZP_env.jl")
# Out:
# score_test (generic function with 1 method)

# %%
function calc_Kt_sym_try(history::Vector{Int}, env::Env)
    MV = []
    his = copy(history)
    t = collect(0:env.Ω*env.dt:2pi)
    #println(length(his))
    for it in 1:length(his)
        sw = pop!(his)
        if(sw==1)
            push!(MV, env.H_0)
        elseif(sw==2)
            push!(MV, env.V_t*sx)
        elseif(sw==3)
            A = pop!(MV)
            B = pop!(MV)
            C = A + B
            push!(MV, C)
        elseif(sw==4)
            A = pop!(MV)
            B = pop!(MV)
            C = -1im*(A*B - B*A)
            push!(MV, C)
        elseif(sw==5)
            A = pop!(MV)
            B = pop!(MV)
            C = (A*B + B*A)/2
            push!(MV, C)
        elseif(sw==6)
            A = pop!(MV)
            S = A.subs(x, t[1])-A.subs(x, t[div(env.t_step,10)])
            if(S==zeros(env.HS_size, env.HS_size))
                B = A
            else
                println("it=$(it): Integral!")
                simplify.(A)
                return A
                B = A.integrate(x)/env.Ω
            end
            push!(MV, B)
        end
        println("it=$(it): $(MV[end])")
    end
    return MV[end]
end
# Out:
# calc_Kt_sym_try (generic function with 1 method)

# %%
en = init_Env_quick(["15", "64", "5", "0.25"], Any[0.3, Int(72), 1.0])
# Out:
# Env(15, 200, 2, 3, 1, 6, 90, 64, 7, 5, 1000, 200, 500, 1, 1.0f-5, 0.9f0, 512, 0.3f0, 0.25f0, 0.1f0, 1.0f0, 100, 4, 10.0f0, 0.4f0, 1.0f0, 0.7f0, 0.5f0, ComplexF32[-2.0f0 + 0.0f0im 0.0f0 + 0.0f0im 0.0f0 + 0.0f0im -0.7f0 + 0.0f0im; 0.0f0 - 0.0f0im 1.0f0 + 0.0f0im -0.7f0 + 0.0f0im 0.0f0 + 0.0f0im; 0.0f0 - 0.0f0im -0.7f0 - 0.0f0im 1.0f0 + 0.0f0im 0.0f0 + 0.0f0im; -0.7f0 - 0.0f0im 0.0f0 - 0.0f0im 0.0f0 - 0.0f0im 0.0f0 + 0.0f0im], ComplexF32[0.0f0 + 0.0f0im -0.4f0 + 0.0f0im -0.4f0 + 0.0f0im 0.0f0 + 0.0f0im; -0.4f0 - 0.0f0im 0.0f0 + 0.0f0im 0.0f0 + 0.0f0im -0.4f0 + 0.0f0im; -0.4f0 - 0.0f0im 0.0f0 - 0.0f0im 0.0f0 + 0.0f0im -0.4f0 + 0.0f0im; 0.0f0 - 0.0f0im -0.4f0 - 0.0f0im -0.4f0 - 0.0f0im 0.0f0 + 0.0f0im], 0.0062831854f0, 72, 1.0f0, 1.0f-6)

# %%
#hist = [6, 6, 6, 6, 3, 1, 4, 2, 1]
#hist = [6, 6, 6, 3, 2, 6, 5, 1, 5, 2, 6, 4, 2, 1]
hist = [6, 3, 1, 2]
a = calc_Kt_sym(hist, en)
# Out:
# it=1: Sym[0 -0.400000005960464*sin(x) -0.400000005960464*sin(x) 0; -0.400000005960464*sin(x) 0 0 -0.400000005960464*sin(x); -0.400000005960464*sin(x) 0 0 -0.400000005960464*sin(x); 0 -0.400000005960464*sin(x) -0.400000005960464*sin(x) 0]
# it=2: ComplexF32[-2.0f0 + 0.0f0im 0.0f0 + 0.0f0im 0.0f0 + 0.0f0im -0.7f0 + 0.0f0im; 0.0f0 - 0.0f0im 1.0f0 + 0.0f0im -0.7f0 + 0.0f0im 0.0f0 + 0.0f0im; 0.0f0 - 0.0f0im -0.7f0 - 0.0f0im 1.0f0 + 0.0f0im 0.0f0 + 0.0f0im; -0.7f0 - 0.0f0im 0.0f0 - 0.0f0im 0.0f0 - 0.0f0im 0.0f0 + 0.0f0im]
# it=3: Sym[-2.00000000000000 -0.400000005960464*sin(x) -0.400000005960464*sin(x) -0.699999988079071; -0.400000005960464*sin(x) 1.00000000000000 -0.699999988079071 -0.400000005960464*sin(x); -0.400000005960464*sin(x) -0.699999988079071 1.00000000000000 -0.400000005960464*sin(x); -0.699999988079071 -0.400000005960464*sin(x) -0.400000005960464*sin(x) 0]
# it=4: Integral!
# ...

# %%
b = sympy.im.(a)
# Out:
# 4×4 Matrix{Sym}:
#                           0  …                            0
#  -0.64000002861023*sin(x)^3     -0.384000017166138*sin(x)^3
#  -0.64000002861023*sin(x)^3     -0.384000017166138*sin(x)^3
#                           0                               0

# %%
c = sympy.re.(a)
# Out:
# 4×4 Matrix{Sym}:
#                          0  …                          0
#  -0.400000005960464*sin(x)     -0.400000005960464*sin(x)
#  -0.400000005960464*sin(x)     -0.400000005960464*sin(x)
#                          0                             0

# %%
d = c.integrate(x) + 1im*b.integrate(x)
# Out:
# 4×4 Matrix{Sym}:
#                                                                                     0  …                                                                                      0
#  I*(-0.213333342870077*cos(x)^3 + 0.64000002861023*cos(x)) + 0.400000005960464*cos(x)     I*(-0.128000005722046*cos(x)^3 + 0.384000017166138*cos(x)) + 0.400000005960464*cos(x)
#  I*(-0.213333342870077*cos(x)^3 + 0.64000002861023*cos(x)) + 0.400000005960464*cos(x)     I*(-0.128000005722046*cos(x)^3 + 0.384000017166138*cos(x)) + 0.400000005960464*cos(x)
#                                                                                     0                                                                                         0

# %%
e = a.integrate(x)

# %%
push!(MV, en.H_0)
# Out:
# 3-element Vector{Any}:
#  Sym[0 -0.400000005960464*sin(x) -0.400000005960464*sin(x) 0; -0.400000005960464*sin(x) 0 0 -0.400000005960464*sin(x); -0.400000005960464*sin(x) 0 0 -0.400000005960464*sin(x); 0 -0.400000005960464*sin(x) -0.400000005960464*sin(x) 0]
#  Sym[0.320000009536743*sin(x)^2 0 0 0.320000009536743*sin(x)^2; 0 0.320000009536743*sin(x)^2 0.320000009536743*sin(x)^2 0; 0 0.320000009536743*sin(x)^2 0.320000009536743*sin(x)^2 0; 0.320000009536743*sin(x)^2 0 0 0.320000009536743*sin(x)^2]
#  ComplexF32[-2.0f0 + 0.0f0im 0.0f0 + 0.0f0im 0.0f0 + 0.0f0im -0.7f0 + 0.0f0im; 0.0f0 - 0.0f0im 1.0f0 + 0.0f0im -0.7f0 + 0.0f0im 0.0f0 + 0.0f0im; 0.0f0 - 0.0f0im -0.7f0 - 0.0f0im 1.0f0 + 0.0f0im 0.0f0 + 0.0f0im; -0.7f0 - 0.0f0im 0.0f0 - 0.0f0im 0.0f0 - 0.0f0im 0.0f0 + 0.0f0im]

# %%
push!(MV, en.V_t*sx)
@show MV
# Out:
# MV = Any[Sym[0 -0.400000005960464*sin(x) -0.400000005960464*sin(x) 0; -0.400000005960464*sin(x) 0 0 -0.400000005960464*sin(x); -0.400000005960464*sin(x) 0 0 -0.400000005960464*sin(x); 0 -0.400000005960464*sin(x) -0.400000005960464*sin(x) 0], Sym[0 -0.400000005960464*sin(x) -0.400000005960464*sin(x) 0; -0.400000005960464*sin(x) 0 0 -0.400000005960464*sin(x); -0.400000005960464*sin(x) 0 0 -0.400000005960464*sin(x); 0 -0.400000005960464*sin(x) -0.400000005960464*sin(x) 0], Sym[0 -0.400000005960464*sin(x) -0.400000005960464*sin(x) 0; -0.400000005960464*sin(x) 0 0 -0.400000005960464*sin(x); -0.400000005960464*sin(x) 0 0 -0.400000005960464*sin(x); 0 -0.400000005960464*sin(x) -0.400000005960464*sin(x) 0]]
# 3-element Vector{Any}:
#  Sym[0 -0.400000005960464*sin(x) -0.400000005960464*sin(x) 0; -0.400000005960464*sin(x) 0 0 -0.400000005960464*sin(x); -0.400000005960464*sin(x) 0 0 -0.400000005960464*sin(x); 0 -0.400000005960464*sin(x) -0.400000005960464*sin(x) 0]
# ...

# %%
A = pop!(MV)
B = pop!(MV)
C = A+B
push!(MV, C)
# Out:
# 2-element Vector{Any}:
#  Sym[0 -0.400000005960464*sin(x) -0.400000005960464*sin(x) 0; -0.400000005960464*sin(x) 0 0 -0.400000005960464*sin(x); -0.400000005960464*sin(x) 0 0 -0.400000005960464*sin(x); 0 -0.400000005960464*sin(x) -0.400000005960464*sin(x) 0]
#  Sym[0 0.64000002861023*I*sin(x)^3 - 0.400000005960464*sin(x) 0.64000002861023*I*sin(x)^3 - 0.400000005960464*sin(x) 0; -0.64000002861023*I*sin(x)^3 - 0.400000005960464*sin(x) 0 0 -0.384000017166138*I*sin(x)^3 - 0.400000005960464*sin(x); -0.64000002861023*I*sin(x)^3 - 0.400000005960464*sin(x) 0 0 -0.384000017166138*I*sin(x)^3 - 0.400000005960464*sin(x); 0 0.384000017166138*I*sin(x)^3 - 0.400000005960464*sin(x) 0.384000017166138*I*sin(x)^3 - 0.400000005960464*sin(x) 0]

# %%
A = pop!(MV)
B = pop!(MV)
C = (A*B + B*A)/2
push!(MV, C)
# Out:
# 2-element Vector{Any}:
#  Sym[0 -0.400000005960464*sin(x) -0.400000005960464*sin(x) 0; -0.400000005960464*sin(x) 0 0 -0.400000005960464*sin(x); -0.400000005960464*sin(x) 0 0 -0.400000005960464*sin(x); 0 -0.400000005960464*sin(x) -0.400000005960464*sin(x) 0]
#  Sym[-0.864000021934509*sin(x)^2 0 0 -0.544000012397766*sin(x)^2; 0 0.0960000066757203*sin(x)^2 0.0960000066757203*sin(x)^2 0; 0 0.0960000066757203*sin(x)^2 0.0960000066757203*sin(x)^2 0; -0.544000012397766*sin(x)^2 0 0 -0.224000002861023*sin(x)^2]

# %%
A = pop!(MV)
B = pop!(MV)
C = -1im*(A*B - B*A)
push!(MV, C)
# Out:
# 2-element Vector{Any}:
#  Sym[0 -0.400000005960464*sin(x) -0.400000005960464*sin(x) 0; -0.400000005960464*sin(x) 0 0 -0.400000005960464*sin(x); -0.400000005960464*sin(x) 0 0 -0.400000005960464*sin(x); 0 -0.400000005960464*sin(x) -0.400000005960464*sin(x) 0]
#  Sym[0 0.64000002861023*I*sin(x)^3 0.64000002861023*I*sin(x)^3 0; -0.64000002861023*I*sin(x)^3 0 0 -0.384000017166138*I*sin(x)^3; -0.64000002861023*I*sin(x)^3 0 0 -0.384000017166138*I*sin(x)^3; 0 0.384000017166138*I*sin(x)^3 0.384000017166138*I*sin(x)^3 0]

# %%
@show A = pop!(MV)
# Out:
# A = pop!(MV) = Sym[0 0.64000002861023*I*sin(x)^3 - 0.400000005960464*sin(x) 0.64000002861023*I*sin(x)^3 - 0.400000005960464*sin(x) 0; -0.64000002861023*I*sin(x)^3 - 0.400000005960464*sin(x) 0 0 -0.384000017166138*I*sin(x)^3 - 0.400000005960464*sin(x); -0.64000002861023*I*sin(x)^3 - 0.400000005960464*sin(x) 0 0 -0.384000017166138*I*sin(x)^3 - 0.400000005960464*sin(x); 0 0.384000017166138*I*sin(x)^3 - 0.400000005960464*sin(x) 0.384000017166138*I*sin(x)^3 - 0.400000005960464*sin(x) 0]
# 4×4 Matrix{Sym}:
#                                                        0  …                                                         0
#  -0.64000002861023*I*sin(x)^3 - 0.400000005960464*sin(x)     -0.384000017166138*I*sin(x)^3 - 0.400000005960464*sin(x)
#  -0.64000002861023*I*sin(x)^3 - 0.400000005960464*sin(x)     -0.384000017166138*I*sin(x)^3 - 0.400000005960464*sin(x)
#                                                        0                                                            0

# %%
S = A.subs(x, t[1])-A.subs(x, t[div(en.t_step,10)])
# Out:
# 4×4 Matrix{Sym}:
#                                         0  …                                         0
#  0.214330731029275 + 0.0984585273472118*I     0.214330731029275 + 0.0590751164083271*I
#  0.214330731029275 + 0.0984585273472118*I     0.214330731029275 + 0.0590751164083271*I
#                                         0                                            0

# %%
(S==zeros(en.HS_size, en.HS_size))
# Out:
# false

# %%
B = A.integrate(x)/en.Ω
#push!(MV, B)

# %%
MV = []
t = collect(0:en.Ω*en.dt:2pi)
his = copy(hist)
# Out:
# 12-element Vector{Int64}:
#  5
#  6
#  3
#  2
#  4
#  2
#  5
#  1
#  5
#  2
#  2
#  2

# %%
typeof(Ks)
# Out:
# Matrix{Sym} (alias for Array{Sym, 2})

# %%
K0 = convert(Matrix{ComplexF32}, Ks.subs(x,t[1]))
# Out:
# 4×4 Matrix{ComplexF32}:
#  0.0+0.0im  0.0+0.0im  0.0+0.0im  0.0+0.0im
#  0.0+0.0im  0.0+0.0im  0.0+0.0im  0.0+0.0im
#  0.0+0.0im  0.0+0.0im  0.0+0.0im  0.0+0.0im
#  0.0+0.0im  0.0+0.0im  0.0+0.0im  0.0+0.0im

# %%
@time Kt = [Hermitian(convert(Matrix{ComplexF32}, Ks.subs(x,t[i]))-K0) for i in 1:en.t_step]
println(Kt[25])
# Out:
#   1.032328 seconds (285.62 k allocations: 17.246 MiB, 10.95% compilation time)
# ComplexF32[0.31873837f0 + 0.0f0im 0.0f0 + 0.0f0im 0.0f0 + 0.0f0im 0.31873837f0 - 0.10159414f0im; 0.0f0 - 0.0f0im 0.31873837f0 + 0.0f0im 0.31873837f0 + 0.0f0im 0.0f0 + 0.0f0im; 0.0f0 - 0.0f0im 0.31873837f0 - 0.0f0im 0.31873837f0 + 0.0f0im 0.0f0 + 0.0f0im; 0.31873837f0 + 0.10159414f0im 0.0f0 - 0.0f0im 0.0f0 - 0.0f0im 0.31873837f0 + 0.0f0im]

# %%
@time Kt = calc_Kt(hist, en)
# Out:
# it: 1
# now: Sym[0 -0.400000005960464*sin(x) -0.400000005960464*sin(x) 0; -0.400000005960464*sin(x) 0 0 -0.400000005960464*sin(x); -0.400000005960464*sin(x) 0 0 -0.400000005960464*sin(x); 0 -0.400000005960464*sin(x) -0.400000005960464*sin(x) 0]
# it: 2
# now: Sym[0 -0.400000005960464*sin(x) -0.400000005960464*sin(x) 0; -0.400000005960464*sin(x) 0 0 -0.400000005960464*sin(x); -0.400000005960464*sin(x) 0 0 -0.400000005960464*sin(x); 0 -0.400000005960464*sin(x) -0.400000005960464*sin(x) 0]
# it: 3
# now: Sym[0 -0.400000005960464*sin(x) -0.400000005960464*sin(x) 0; -0.400000005960464*sin(x) 0 0 -0.400000005960464*sin(x); -0.400000005960464*sin(x) 0 0 -0.400000005960464*sin(x); 0 -0.400000005960464*sin(x) -0.400000005960464*sin(x) 0]
# it: 4
# now: Sym[0.320000009536743*sin(x)^2 0 0 0.320000009536743*sin(x)^2; 0 0.320000009536743*sin(x)^2 0.320000009536743*sin(x)^2 0; 0 0.320000009536743*sin(x)^2 0.320000009536743*sin(x)^2 0; 0.320000009536743*sin(x)^2 0 0 0.320000009536743*sin(x)^2]
# ...

# %%
@time Hr = calc_Hr(Kt ,en)
# Out:
#   0.005746 seconds (3.97 k allocations: 667.844 KiB)
# 100-element Vector{Hermitian{ComplexF32, Matrix{ComplexF32}}}:
#  [-2.000001f0 + 0.0f0im -0.025116209f0 + 0.0f0im -0.025116209f0 + 0.0f0im -0.700001f0 + 5.192927f-9im; -0.025116209f0 - 0.0f0im 0.999999f0 + 0.0f0im -0.700001f0 + 2.5874165f-9im -0.025116209f0 + 0.0f0im; -0.025116209f0 - 0.0f0im -0.700001f0 - 2.5874165f-9im 0.999999f0 + 0.0f0im -0.025116209f0 + 0.0f0im; -0.700001f0 - 5.192927f-9im -0.025116209f0 - 0.0f0im -0.025116209f0 - 0.0f0im -1.019044f-6 + 0.0f0im]
# ...

# %%
@time loss = calc_loss(Hr, en)
# Out:
#   0.000114 seconds (299 allocations: 55.766 KiB)
# 0.40692902f0

# %%
@time score = calc_score(hist, en)
# Out:
# history: [5, 6, 3, 2, 4, 2, 5, 1, 5, 2, 2, 2]
#   0.970609 seconds (96.49 k allocations: 4.560 MiB, 4.04% compilation time)
# 0.40692902f0
